# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import scipy as sp
from scipy import stats
import numpy as np

COVIDDataSet = pd.read_csv("c:\michael_docs\git repositories\covid-tracking-data/data/states_daily_4pm_et.csv")
COVIDDataSet
# Out:
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200526    AK     411.0   44553.0      NaN                   12.0
# 1     20200526    AL   15396.0  178363.0      NaN                    NaN
# 2     20200526    AR    6180.0  105593.0      NaN                  107.0
# 3     20200526    AS       0.0     124.0      NaN                    NaN
# 4     20200526    AZ   16783.0  173948.0      NaN                  818.0
# ...        ...   ...       ...       ...      ...                    ...
# 4604  20200126    WA       1.0       NaN      NaN                    NaN
# 4605  20200125    WA       1.0       NaN      NaN                    NaN
# 4606  20200124    WA       1.0       NaN      NaN                    NaN
# 4607  20200123    WA       1.0       NaN      NaN                    NaN
# 4608  20200122    WA       1.0       NaN      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
NCDataFrame = COVIDDataSet[COVIDDataSet.state == 'NC']
NCDataFrame = NCDataFrame[NCDataFrame.date >= 20200401]
NCDataFrame = NCDataFrame[["date", "state", "positiveIncrease", "totalTestResultsIncrease"]]

# %%
linRegress  = stats.linregress(NCDataFrame["positiveIncrease"], NCDataFrame["totalTestResultsIncrease"])

# %%
linRegress.rvalue
# Out:
# 0.7400415751406587
