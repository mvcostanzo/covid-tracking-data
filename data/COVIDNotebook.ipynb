# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd
import scipy as sp
from scipy import stats
import numpy as np

COVIDDataSet = pd.read_csv("c:\michael_docs\git repositories\covid-tracking-data/data/states_daily_4pm_et.csv")
COVIDDataSet
# Out:
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200524    AK     408.0   43099.0      NaN                   10.0
# 1     20200524    AL   14327.0  171472.0      NaN                    NaN
# 2     20200524    AR    5922.0  102659.0      NaN                   86.0
# 3     20200524    AS       0.0     124.0      NaN                    NaN
# 4     20200524    AZ   16339.0  167302.0      NaN                  804.0
# ...        ...   ...       ...       ...      ...                    ...
# 4492  20200126    WA       1.0       NaN      NaN                    NaN
# 4493  20200125    WA       1.0       NaN      NaN                    NaN
# 4494  20200124    WA       1.0       NaN      NaN                    NaN
# 4495  20200123    WA       1.0       NaN      NaN                    NaN
# 4496  20200122    WA       1.0       NaN      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                        NaN             NaN              NaN
# 1                     1612.0             NaN            537.0
# 2                      598.0             NaN              NaN
# 3                        NaN             NaN              NaN
# 4                     1945.0           322.0              NaN
# ...                      ...             ...              ...
# 4492                     NaN             NaN              NaN
# 4493                     NaN             NaN              NaN
# 4494                     NaN             NaN              NaN
# 4495                     NaN             NaN              NaN
# 4496                     NaN             NaN              NaN
#
#       onVentilatorCurrently  ...  hospitalized   total totalTestResults  \
# 0                       NaN  ...           NaN   43507            43507
# 1                       NaN  ...        1612.0  185799           185799
# 2                      17.0  ...         598.0  108581           108581
# 3                       NaN  ...           NaN     124              124
# 4                     201.0  ...        1945.0  183641           183641
# ...                     ...  ...           ...     ...              ...
# 4492                    NaN  ...           NaN       1                1
# 4493                    NaN  ...           NaN       1                1
# 4494                    NaN  ...           NaN       1                1
# 4495                    NaN  ...           NaN       1                1
# 4496                    NaN  ...           NaN       1                1
#
#       posNeg fips deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0      43507    2           0.0                   0.0            1156.0
# 1     185799    1           5.0                  23.0            2734.0
# 2     108581    5           3.0                   8.0            5224.0
# 3        124   60           0.0                   0.0               0.0
# 4     183641    4           1.0                  15.0            2902.0
# ...      ...  ...           ...                   ...               ...
# 4492       1   53           0.0                   0.0               0.0
# 4493       1   53           0.0                   0.0               0.0
# 4494       1   53           0.0                   0.0               0.0
# 4495       1   53           0.0                   0.0               0.0
# 4496       1   53           NaN                   NaN               NaN
#
#       positiveIncrease  totalTestResultsIncrease
# 0                  0.0                    1156.0
# 1                389.0                    3123.0
# 2                310.0                    5534.0
# 3                  0.0                       0.0
# 4                300.0                    3202.0
# ...                ...                       ...
# 4492               0.0                       0.0
# 4493               0.0                       0.0
# 4494               0.0                       0.0
# 4495               0.0                       0.0
# 4496               NaN                       NaN
#
# [4497 rows x 27 columns]

# %%
NCDataFrame = COVIDDataSet[COVIDDataSet.state == 'NC']
NCDataFrame = NCDataFrame[NCDataFrame.date >= 20200401]
NCDataFrame = NCDataFrame[["date", "state", "positiveIncrease", "totalTestResultsIncrease"]]

# %%
stats.linregress(NCDataFrame["positiveIncrease"], NCDataFrame["totalTestResultsIncrease"])
# Out:
# LinregressResult(slope=17.083994160037857, intercept=-1066.3460950493036, rvalue=0.7643219853201889, pvalue=1.7552546167116775e-11, stderr=1.9987563153088013)
